# %% [markdown]
# # The Relationship between Life Expectancy (Years) & GDP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

gdp_df = pd.read_csv('all_data.csv')
gdp_df
# Out:
#      Country  Year  Life expectancy at birth (years)           GDP
# 0      Chile  2000                              77.3  7.786093e+10
# 1      Chile  2001                              77.3  7.097992e+10
# 2      Chile  2002                              77.8  6.973681e+10
# 3      Chile  2003                              77.9  7.564346e+10
# 4      Chile  2004                              78.0  9.921039e+10
# ..       ...   ...                               ...           ...
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10
#
# [96 rows x 4 columns]

# %%
unique_list = gdp_df.Country.unique().tolist()
print('The 6 countries are: ' + str(unique_list))
# Out:
# The 6 countries are: ['Chile', 'China', 'Germany', 'Mexico', 'United States of America', 'Zimbabwe']

# %%
plt.figure(figsize = (20,15))

plt.subplot(2,3,4)
plt.scatter(gdp_df_Chile.GDP, gdp_df_Chile['Life expectancy at birth (years)'], label = 'r = 0.9499')
plt.legend(fontsize = 15)
plt.title('Chile', fontsize =15)
plt.xlabel('GDP (trillions USD)', fontsize =12)
plt.ylabel('Life expectancy (years)', fontsize =12)

plt.subplot(2,3,1)
plt.scatter(gdp_df_China.GDP, gdp_df_China['Life expectancy at birth (years)'], color = 'Red', label = 'r = 0.9085')
plt.legend(fontsize = 15)
plt.title('China', fontsize =15)
plt.xlabel('GDP (trillions USD)', fontsize =12)
plt.ylabel('Life expectancy (years)', fontsize =12)

plt.subplot(2,3,3)
plt.scatter(gdp_df_Germany.GDP, gdp_df_Germany['Life expectancy at birth (years)'], label = 'r = 0.9327', color = 'Orange')
plt.legend(fontsize = 15)
plt.title('Germany', fontsize =15)
plt.xlabel('GDP (trillions USD)', fontsize = 12)
plt.ylabel('Life expectancy (years)', fontsize = 12)

plt.subplot(2,3,2)
plt.scatter(gdp_df_Mexico.GDP, gdp_df_Mexico['Life expectancy at birth (years)'], color = 'Green', label = 'r = 0.9322')
plt.legend(fontsize = 15)
plt.title('Mexico', fontsize = 15)
plt.xlabel('GDP (trillions USD)', fontsize = 12)
plt.ylabel('Life expectancy (years)', fontsize = 12)

plt.subplot(2,3,6)
plt.scatter(gdp_df_usa.GDP, gdp_df_usa['Life expectancy at birth (years)'], color = 'Blue',label = 'r = 0.9817')
plt.legend(fontsize = 15)
plt.title('USA', fontsize = 15)
plt.xlabel('GDP (trillions USD)', fontsize = 12)
plt.ylabel('Life expectancy (years)', fontsize = 12)
           
plt.subplot(2,3,5)
plt.scatter(gdp_df_Zimbabwe.GDP, gdp_df_Zimbabwe['Life expectancy at birth (years)'], color = 'Black', label = 'r = 0.9662')
plt.legend(fontsize = 15)
plt.title('Zimbabwe', fontsize = 15)
plt.xlabel('GDP (trillions USD)', fontsize = 12)
plt.ylabel('Life expectancy (years)', fontsize = 12)

plt.suptitle('Relationship between Life Expectancy & GDP', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Relationship between Life Expectancy & GDP')

# %%
plt.figure(figsize = (20,15))

plt.subplot(2,3,1)
plt.plot(gdp_df_Zimbabwe.Year, gdp_df_Zimbabwe['Life expectancy at birth (years)'], color = 'Red')
plt.title('Zimbabwe', fontsize = 15)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Life expectancy at birth (years)', fontsize = 15)

plt.subplot(2,3,2)
plt.plot(gdp_df_Chile.Year, gdp_df_Chile['Life expectancy at birth (years)'], color = 'Green')
plt.title('Chile', fontsize = 15)
plt.xlabel('Years', fontsize =15)
plt.ylabel('Life expectancy at birth (years)', fontsize =15)

plt.subplot(2,3,3)
plt.plot(gdp_df_usa.Year, gdp_df_usa['Life expectancy at birth (years)'], color = 'Blue')
plt.title('USA', fontsize = 15)
plt.xlabel('Years', fontsize =15)
plt.ylabel('Life expectancy at birth (years)', fontsize =15)

plt.subplot(2,3,4)
plt.plot(gdp_df_Mexico.Year, gdp_df_Mexico['Life expectancy at birth (years)'], color = 'Orange')
plt.title('Mexico', fontsize = 15)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Life expectancy at birth (years)', fontsize = 15)

plt.subplot(2,3,5)
plt.plot(gdp_df_China.Year, gdp_df_China['Life expectancy at birth (years)'], color = 'Purple')
plt.title('China', fontsize = 15)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Life expectancy at birth (years)', fontsize = 15)

plt.subplot(2,3,6)
plt.plot(gdp_df_Germany.Year, gdp_df_Germany['Life expectancy at birth (years)'])
plt.title('Germany', fontsize = 15)
plt.xlabel('Years', fontsize = 15)
plt.ylabel('Life expectancy at birth (years)', fontsize = 15)

plt.suptitle('Change in Life Expectancy 2000-2015', fontsize = 20)
plt.show()
